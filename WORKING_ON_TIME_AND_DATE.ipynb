# %%
import pandas as pd
df=pd.read_csv('weatherHistory.csv')
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %% [markdown]
# Part A

# %%
s1=pd.Series(df['Precip Type'])
s2=pd.Series(df['Temperature (C)'])

s2.groupby(s1).mean()
# Out:
# Precip Type
# rain    13.852989
# snow    -3.270885
# Name: Temperature (C), dtype: float64

# %% [markdown]
# Part B

# %%
temp1=pd.read_csv('weatherHistory.csv').head()

temp1['Formatted Date']=pd.to_datetime(temp1['Formatted Date'],utc=True)

temp1.index=temp1['Formatted Date']

temp1.asfreq(freq='30T',method='ffill')
# Out:
#                                      Formatted Date        Summary  \
# Formatted Date
# 2006-03-31 22:00:00+00:00 2006-03-31 22:00:00+00:00  Partly Cloudy
# 2006-03-31 22:30:00+00:00 2006-03-31 22:00:00+00:00  Partly Cloudy
# 2006-03-31 23:00:00+00:00 2006-03-31 23:00:00+00:00  Partly Cloudy
# 2006-03-31 23:30:00+00:00 2006-03-31 23:00:00+00:00  Partly Cloudy
# 2006-04-01 00:00:00+00:00 2006-04-01 00:00:00+00:00  Mostly Cloudy
# 2006-04-01 00:30:00+00:00 2006-04-01 00:00:00+00:00  Mostly Cloudy
# 2006-04-01 01:00:00+00:00 2006-04-01 01:00:00+00:00  Partly Cloudy
# 2006-04-01 01:30:00+00:00 2006-04-01 01:00:00+00:00  Partly Cloudy
# 2006-04-01 02:00:00+00:00 2006-04-01 02:00:00+00:00  Mostly Cloudy
#
#                           Precip Type  Temperature (C)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00        rain         9.472222
# 2006-03-31 22:30:00+00:00        rain         9.472222
# 2006-03-31 23:00:00+00:00        rain         9.355556
# ...

# %% [markdown]
# Part C

# %%
temp2=pd.read_csv('weatherHistory.csv').head()

temp2['Formatted Date']=pd.to_datetime(temp2['Formatted Date'],utc=True)

temp2['NEW']=temp2['Formatted Date'].dt.strftime('%Y-%m')



temp2.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %%
temp2['NEW']=pd.to_datetime(temp2['NEW'])
temp2['NEW']=temp2['NEW'].apply(lambda z:pd.datetime(z.year,z.month,23))

temp2.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %% [markdown]
# Part D

# %%
#summary and wind speed

temp3=pd.read_csv('weatherHistory.csv')

m4=temp3.groupby(['Summary','Precip Type'])['Humidity'].mean()
m4
# Out:
# Summary                              Precip Type
# Breezy                               rain           0.620000
#                                      snow           0.700000
# Breezy and Dry                       rain           0.260000
# Breezy and Foggy                     rain           0.951250
#                                      snow           0.934815
# Breezy and Mostly Cloudy             rain           0.632082
#                                      snow           0.730769
# Breezy and Overcast                  rain           0.762331
#                                      snow           0.770000
# Breezy and Partly Cloudy             rain           0.543984
#                                      snow           0.644286
# Clear                                rain           0.715103
#                                      snow           0.824339
# Dangerously Windy and Partly Cloudy  rain           0.490000
# Drizzle                              rain           0.867949
# ...

# %%
m4.groupby(level=0,group_keys=False).nlargest(5)
# Out:
# Summary                              Precip Type
# Breezy                               snow           0.700000
#                                      rain           0.620000
# Breezy and Dry                       rain           0.260000
# Breezy and Foggy                     rain           0.951250
#                                      snow           0.934815
# Breezy and Mostly Cloudy             snow           0.730769
#                                      rain           0.632082
# Breezy and Overcast                  snow           0.770000
#                                      rain           0.762331
# Breezy and Partly Cloudy             snow           0.644286
#                                      rain           0.543984
# Clear                                snow           0.824339
#                                      rain           0.715103
# Dangerously Windy and Partly Cloudy  rain           0.490000
# Drizzle                              rain           0.867949
# ...

# %% [markdown]
# Part E

# %%
mybins = pd.cut(df['Visibility (km)'],bins=4)
mybins

temp=pd.read_csv('weatherHistory.csv')
temp['Bins']=mybins

r=temp.groupby('Bins').size()

r
# Out:
# Bins
# (-0.0161, 4.025]     9922
# (4.025, 8.05]       12780
# (8.05, 12.075]      46911
# (12.075, 16.1]      26840
# dtype: int64
